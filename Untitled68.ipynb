# %% [markdown]
# Medical Cost Personal Insurance Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn import metrics


import warnings 
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

# %% [markdown]
# importing the dependencies

# %%
#Loading the data 

df = pd.read_csv("C:\\Users\\user\\Downloads\\medical_cost_insurance.csv")

df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#first 5 rows of the data frame 
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# number of rows and coloumns 
df.shape
# Out:
# (1338, 7)

# %%
#Data set information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#checking for missing value 
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#statistical measures of the dataset
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#distribution of age value 
# Replace inf values with NaN
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# Drop rows with NaN in 'age' if necessary (optional)
df = df.dropna(subset=['age'])

# Plot the distribution of age values
sns.set()
plt.figure(figsize=(6,6))
sns.histplot(df['age'], kde=True)
plt.title('Distribution of Age')
plt.show()

# %%
# Plotting the count of each category in the 'sex' column
plt.figure(figsize=(6, 6))
sns.countplot(x='sex', data=df)  
plt.title('Sex Distribution')
plt.show()

# %%
df['sex'].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
#bmi distribution
sns.set()
plt.figure(figsize=(6,6))
sns.histplot(df['bmi'], kde=True)
plt.title('Distribution of BMI')
plt.show()

# %% [markdown]
# Normal BMI range -> 18.5 - 24.9

# %%
#children coloumn
plt.figure(figsize=(6,6))
sns.countplot(x='children',data=df)
plt.title('children')
plt.show()

# %%
df['children'].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
#smoker coloumn
plt.figure(figsize=(6,6))
sns.countplot(x='smoker',data=df)
plt.title('smoker')
plt.show()

# %%
#region coloumn
plt.figure(figsize=(6,6))
sns.countplot(x='region',data=df)
plt.title('region')
plt.show()

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
#distribution of charges value 
sns.set()
plt.figure(figsize=(6, 6))
sns.histplot(df['charges'], kde=True)  # Adjust the column name if necessary
plt.title('Distribution of Charges')
plt.xlabel('Charges')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.scatterplot(x='bmi', y='charges', hue='sex', data=df, palette='coolwarm')  
plt.title('BMI vs Charges')
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.legend(title='Sex')  # Optional: adds a title to the legend
plt.show()

# %% [markdown]
# DATA PRE PROCESSING
#
# Encoding the categorical features

# %%
# Encoding 'sex' column
df.replace({'sex': {'male': 0, 'female': 1}}, inplace=True)

# Encoding 'smoker' column
df.replace({'smoker': {'yes': 1, 'no': 0}}, inplace=True)  # Changed values to match the description (yes = 1, no = 0)

# Encoding 'region' column
df.replace({'region': {'southeast': 0, 'southwest': 1, 'northeast': 2, 'northwest': 3}}, inplace=True)

# %% [markdown]
# Splitting  the features and  Target

# %%
# Splitting the DataFrame into features (X) and target (Y)
X = df.drop(columns='charges', axis=1)
Y = df['charges']

# %%
print(X)
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       1       1
# 1      18    0  33.770         1       0       0
# 2      28    0  33.000         3       0       0
# 3      33    0  22.705         0       0       3
# 4      32    0  28.880         0       0       3
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       0       3
# 1334   18    1  31.920         0       0       2
# 1335   18    1  36.850         0       0       0
# 1336   21    1  25.800         0       0       1
# 1337   61    1  29.070         0       1       3
#
# [1338 rows x 6 columns]

# %%
print(Y)
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %% [markdown]
# Splitting the data into training data and testing data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2,random_state=2)

# %% [markdown]
# Model Training
#
#
# Linear Regression

# %%
#Loading the Linear Regression model
regressor = LinearRegression()

# %%
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Model Evaluation

# %%
#prediction on traing data
training_data_prediction=regressor.predict(X_train)

# %%
#R squared value
r2_train = metrics.r2_score(Y_train, training_data_prediction)
print('R squared value:', r2_train)
# Out:
# R squared value: 0.751505643411174

# %%
#prediction on test data
test_data_prediction=regressor.predict(X_test)

# %%
#R squared value
r2_test = metrics.r2_score(Y_test, test_data_prediction)
print('R squared value:', r2_test)
# Out:
# R squared value: 0.7447273869684077

# %% [markdown]
# Building a Prediactive System

# %%
# Example data with 'children' feature
data = {
    'age': [23, 45, 34],
    'sex': [1, 0, 1],
    'bmi': [22.0, 28.5, 25.6],
    'smoker': [0, 1, 0],
    'region': [0, 1, 2],
    'children': [2, 0, 1]  # Ensure 'children' is included
}
X = pd.DataFrame(data)
Y = pd.Series([3000, 4000, 3500])

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Define and train the model
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Input data for prediction with all required features
input_data = {
    'age': [46],
    'sex': [1],         # Assuming encoding where 1 represents male
    'bmi': [33.44],
    'smoker': [0],      # Assuming encoding where 0 represents non-smoker
    'region': [0],      # Assuming encoding with 0 for southeast
    'children': [1]     # Ensure 'children' feature is included
}

# Convert to DataFrame with correct column names and order
input_data_df = pd.DataFrame(input_data)

# Make prediction
prediction = regressor.predict(input_data_df)
print('Prediction:', prediction[0])

# Print the result with a formatted string
print(f'The insurance cost is USD {prediction[0]:,.2f}')
# Out:
# Prediction: 4087.4222322164755
# The insurance cost is USD 4,087.42

# %%
input_data = {
    'age': [60],
    'sex': [1],         # Assuming encoding where 1 represents male
    'bmi': [25.84],
    'smoker': [0],      # Assuming encoding where 0 represents non-smoker
    'region': [2],      # Assuming encoding with 0 for southeast
    'children': [1]     # Ensure 'children' feature is included
}

# Convert to DataFrame with correct column names and order
input_data_df = pd.DataFrame(input_data)

# Make prediction
prediction = regressor.predict(input_data_df)
print('Prediction:', prediction[0])

# Print the result with a formatted string
print(f'The insurance cost is USD {prediction[0]:,.2f}')
